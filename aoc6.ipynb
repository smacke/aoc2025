# %%
# %flow deregister dataflow

# %%
import numpy as np

# %%
inp = """
123 328  51 64 
 45 64  387 23 
  6 98  215 314
*   +   *   +  
""".strip().splitlines()

# %%
with open("6.txt", "r") as f:
    inp = f.read().strip().splitlines()

# %%
rows = inp |> map[$.strip().split()] |> list

# %%
rows, ops = rows[:-1], rows[-1]

# %%
rows = rows |> map[$ |> map[int] |> list] |> list |> np.array($).T

# %%
zip(ops, rows) |> map[$ *|> reduce({"*": f[$ * $], "+": f[$ + $]}[$], $)] |> sum
# Out:
# 5060053676136
