# %%
# %flow deregister dataflow

# %%
inp = """
7,1
11,1
11,7
9,7
9,5
2,5
2,3
7,3
""".strip().splitlines()

# %%
with open("9.txt", "r") as f:
    inp = f.read().strip().splitlines()

# %%
arr = inp |> map[$.strip().split(",") |> map[int] |> list] |> list

# %%
area = f[(1 + abs($p1[0] - $p2[0])) * (1 + abs($p1[1] - $p2[1]))]

# %%
# %flow register dataflow

# %%
ans = 0
for r1 in arr:
    for r2 in arr:
        ans = max(ans, area(r1, r2))

# %%
ans
# Out:
# 4748826374
