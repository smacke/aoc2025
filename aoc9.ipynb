# %%
# %load_ext nbpipes

# %%
from tqdm import tqdm

# %%
inp = """
7,1
11,1
11,7
9,7
9,5
2,5
2,3
7,3
""".strip().splitlines()

# %%
with open("9.txt", "r") as f:
    inp = f.read().strip().splitlines()

# %%
arr = inp |> map[$.strip().split(",") |> map[int] |> tuple]

# %%
def area(r1, r2):
    return (1 + abs(r1[0] - r2[0])) * (1 + abs(r1[1] - r2[1]))

# %%
# part 1
ans = 0
for r1 in tqdm(arr):
    for r2 in arr:
        ans = max(ans, area(r1, r2))
ans
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 496/496 [00:00<00:00, 8564.14it/s]
# 4748826374

# %%
def orient(px, py, qx, qy, rx, ry):
    return (qx - px) * (ry - py) - (qy - py) * (rx - px)

def intersect(a, b, c, d):
    ax, ay = a; bx, by = b; cx, cy = c; dx, dy = d
    o1 = orient(ax, ay, bx, by, cx, cy)
    o2 = orient(ax, ay, bx, by, dx, dy)
    o3 = orient(cx, cy, dx, dy, ax, ay)
    o4 = orient(cx, cy, dx, dy, bx, by)
    return o1 * o2 <= 0 and o3 * o4 < 0

# %%
# part 2
ans = 0
for i, a in enumerate(tqdm(arr)):
    for j, b in enumerate(arr):
        if j >= i:
            break
        for k, c in enumerate(arr):
            d = arr[(k + 1)%len(arr)]
            if intersect(a, b, c, d):
                break
            ax, ay = a
            bx, by = b
            if intersect((ax, by), (bx, ay), c, d):
                break
        else:
            ans = max(ans, area(a, b))
ans
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 496/496 [00:32<00:00, 15.46it/s]
# 1554370486
